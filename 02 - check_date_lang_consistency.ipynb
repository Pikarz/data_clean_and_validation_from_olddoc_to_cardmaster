# %% [markdown]
# <a href="https://colab.research.google.com/github/Pikarz/data_clean_and_validation_from_olddoc_to_cardmaster/blob/main/02%20-%20check_date_lang_consistency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check date and language consistency
# This notebook's main objective is to check if the date is in the correct format if it exists and if it doesn't it uses a default dete. The notebook also checks if the language field is consistent with the expansion of the collectible (IE: Expansion $y$ can only have cards that are Japanese).
#
# The notebook takes as input the output of the precedent notebook and adds the following fields:
# - date_comment: states if the date has as correct format (OK) or not
# - language_comment: states if the language is consistent with the expansion (OK) or not

# %%
import psycopg2
import pandas as pd
from datetime import datetime

def is_valid_date(date_string):
    formats = ["%Y-%m-%d", "%Y-%m-%d %H:%M:%S"]
    if pd.isna(date_string): # it's valid if it's empty
      return True

    for format_str in formats:
        try:
            datetime.strptime(date_string, format_str)
            return True
        except ValueError:
            pass

    return False

def check_date(db_params, data_path, default_date):
  conn = None
  curr = None
  try:
    conn = psycopg2.connect(**db_params)
    curr = conn.cursor()
  except Exception as e:
    print(f"Error while connecting to the DB: {e}")
    return

  df = pd.read_csv(data_path)
  if 'date_comment' not in df.columns:
    df['date_comment'] = ''

  for i, row in df.iterrows():
    if row['date_comment'] == 'OK': # if a row has a status different than -1 it has already been checked, so we skip it
      continue

    buying_date = row['B-Date']
    selling_date = row['S-Date']
    if pd.isna(buying_date):
      if not pd.isna(selling_date):
        print(f"Buying date is missing: inserting it as selling date for row {i}")
        buying_date = selling_date
      else:
        print(f"Buying date is missing: inserting it as default date for row {i}")
        buying_date = default_date
      df.at[i, 'B-Date'] = buying_date
    if pd.isna(selling_date) and not pd.isna(row['S-Price']):
      print(f"Selling date is missing: inserting it as buying date for row {i}")
      selling_date = buying_date
      df.at[i, 'S-Date'] = selling_date
    is_valid_buyingdate = is_valid_date(buying_date)
    is_valid_sellingdate = is_valid_date(selling_date)
    if not is_valid_buyingdate and not is_valid_sellingdate:
      df.at[i, 'date_comment'] = 'ERROR! Buying date and Selling date are not valid'
    elif not is_valid_buyingdate:
      df.at[i, 'date_comment'] = 'ERROR! Buying date is not valid'
    elif not is_valid_sellingdate:
      df.at[i, 'date_comment'] = 'ERROR! Selling date is not valid'
    else:
      df.at[i, 'date_comment'] = 'OK'
    df.to_csv(data_path, index=False)

# %%
def is_valid_language(curr, expansion, language):
    language_query = """
        SELECT language
        FROM AllowedExpansionLanguage
        WHERE expansion=%s
    """
    # Execute the query and fetch all results
    curr.execute(language_query, (expansion,))
    languages = curr.fetchall()

    # Check if the given language is in the list of languages
    return language in [lang[0] for lang in languages]

def check_language(db_params, data_path):
  conn = None
  curr = None
  try:
    conn = psycopg2.connect(**db_params)
    curr = conn.cursor()
  except Exception as e:
    print(f"Error while connecting to the DB: {e}")
    return

  df = pd.read_csv(data_path)
  if 'language_comment' not in df.columns:
    df['language_comment'] = ''

  for i, row in df.iterrows():
    if row['language_comment'] == 'OK':
      continue
    expansion = row['Set']
    language = row['Lang']
    if is_valid_language(curr, expansion, language):
      df.at[i, 'language_comment'] = 'OK'
    else:
      df.at[i, 'language_comment'] = 'ERROR: invalid language'
    df.to_csv(data_path, index=False)

# %%
data_path = 'H:/My Drive/pkmn/pok_swap.csv'

db_params = {
    'host': '192.168.example.example',
    'port': '5432',
    'database': 'cardmaster',
    'user': 'example',
    'password': 'example'
}

check_date(db_params, data_path, default_date='2020-01-01')
check_language(db_params, data_path)
# Out:
# Buying date is missing: inserting it as selling date for row 327
# Buying date is missing: inserting it as selling date for row 328
# Buying date is missing: inserting it as selling date for row 329
# Buying date is missing: inserting it as selling date for row 330
# Buying date is missing: inserting it as selling date for row 331
# Buying date is missing: inserting it as selling date for row 332
# Buying date is missing: inserting it as selling date for row 333
# Buying date is missing: inserting it as selling date for row 334
# Buying date is missing: inserting it as selling date for row 335
# Buying date is missing: inserting it as default date for row 336
# Buying date is missing: inserting it as selling date for row 337
# Buying date is missing: inserting it as selling date for row 338
# Buying date is missing: inserting it as selling date for row 339
# Buying date is missing: inserting it as default date for row 340
# Buying date is missing: inserting it as default date for row 341
# Buying date is missing: inserting it as selling date for row 342
# Buying date is missing: inserting it as selling date for row 343
# Buying date is missing: inserting it as default date for row 344
# Buying date is missing: inserting it as default date for row 345
# Buying date is missing: inserting it as default date for row 346
# Buying date is missing: inserting it as default date for row 347
# Buying date is missing: inserting it as default date for row 348
# Buying date is missing: inserting it as selling date for row 349
# Buying date is missing: inserting it as default date for row 350
# Buying date is missing: inserting it as selling date for row 351
# Buying date is missing: inserting it as default date for row 352
# Buying date is missing: inserting it as selling date for row 353
# Buying date is missing: inserting it as selling date for row 354
# Buying date is missing: inserting it as default date for row 355
# Buying date is missing: inserting it as default date for row 356
# Buying date is missing: inserting it as selling date for row 357
# Buying date is missing: inserting it as default date for row 358
# Buying date is missing: inserting it as selling date for row 359
# Buying date is missing: inserting it as default date for row 360
# Buying date is missing: inserting it as default date for row 361
# Buying date is missing: inserting it as default date for row 362
# Buying date is missing: inserting it as selling date for row 363
# Buying date is missing: inserting it as selling date for row 364
# Buying date is missing: inserting it as default date for row 365
# Buying date is missing: inserting it as default date for row 366
# Buying date is missing: inserting it as default date for row 367
# Buying date is missing: inserting it as default date for row 368
# Buying date is missing: inserting it as default date for row 369
# Buying date is missing: inserting it as default date for row 370
# Buying date is missing: inserting it as default date for row 371
# Buying date is missing: inserting it as default date for row 372
# Buying date is missing: inserting it as default date for row 373
# Buying date is missing: inserting it as default date for row 374
# Buying date is missing: inserting it as default date for row 375
# Buying date is missing: inserting it as default date for row 376
# Buying date is missing: inserting it as default date for row 377
# Buying date is missing: inserting it as default date for row 378
# Buying date is missing: inserting it as default date for row 379
# Buying date is missing: inserting it as default date for row 380
# Buying date is missing: inserting it as default date for row 381
# Buying date is missing: inserting it as selling date for row 382
# Buying date is missing: inserting it as selling date for row 383
# Buying date is missing: inserting it as selling date for row 384
# Buying date is missing: inserting it as selling date for row 385
# Buying date is missing: inserting it as selling date for row 386
# Buying date is missing: inserting it as selling date for row 387
# Buying date is missing: inserting it as selling date for row 388
# Buying date is missing: inserting it as selling date for row 389
# Buying date is missing: inserting it as default date for row 390
# Buying date is missing: inserting it as default date for row 391
# Buying date is missing: inserting it as default date for row 392
# Buying date is missing: inserting it as default date for row 393
# Buying date is missing: inserting it as default date for row 394
# Buying date is missing: inserting it as default date for row 395
# Buying date is missing: inserting it as default date for row 396
# Buying date is missing: inserting it as default date for row 397
# Buying date is missing: inserting it as default date for row 398
# Buying date is missing: inserting it as default date for row 399
# Buying date is missing: inserting it as selling date for row 400
# Buying date is missing: inserting it as selling date for row 401
# Buying date is missing: inserting it as selling date for row 402
# Buying date is missing: inserting it as selling date for row 403
# Buying date is missing: inserting it as selling date for row 404
# Buying date is missing: inserting it as selling date for row 405
# Buying date is missing: inserting it as selling date for row 406
# Buying date is missing: inserting it as selling date for row 407
# Buying date is missing: inserting it as selling date for row 408
# Buying date is missing: inserting it as selling date for row 409
# Buying date is missing: inserting it as selling date for row 410
# Buying date is missing: inserting it as default date for row 411
# Buying date is missing: inserting it as default date for row 412
# Buying date is missing: inserting it as default date for row 413
# Buying date is missing: inserting it as default date for row 414
# Buying date is missing: inserting it as default date for row 415
# Buying date is missing: inserting it as default date for row 416
# Buying date is missing: inserting it as selling date for row 417
# Buying date is missing: inserting it as default date for row 418
# Buying date is missing: inserting it as default date for row 419
# Buying date is missing: inserting it as default date for row 420
# Buying date is missing: inserting it as default date for row 421
# Buying date is missing: inserting it as default date for row 422
# Buying date is missing: inserting it as default date for row 423
# Buying date is missing: inserting it as default date for row 424
# Buying date is missing: inserting it as default date for row 425
# Buying date is missing: inserting it as default date for row 426
# Buying date is missing: inserting it as default date for row 427
# Buying date is missing: inserting it as default date for row 428
# Buying date is missing: inserting it as selling date for row 429
# Buying date is missing: inserting it as selling date for row 430
# Buying date is missing: inserting it as selling date for row 431
# Buying date is missing: inserting it as selling date for row 432
# Buying date is missing: inserting it as selling date for row 433
# Buying date is missing: inserting it as selling date for row 434
# Buying date is missing: inserting it as selling date for row 435
# Buying date is missing: inserting it as selling date for row 436
# Buying date is missing: inserting it as selling date for row 437
# Buying date is missing: inserting it as selling date for row 438
# Buying date is missing: inserting it as selling date for row 439
# Buying date is missing: inserting it as default date for row 440
# Buying date is missing: inserting it as selling date for row 441
# Buying date is missing: inserting it as selling date for row 442
# Buying date is missing: inserting it as default date for row 443
# Buying date is missing: inserting it as default date for row 444
# Buying date is missing: inserting it as selling date for row 445
# Buying date is missing: inserting it as selling date for row 446
# Buying date is missing: inserting it as default date for row 447
# Buying date is missing: inserting it as default date for row 448
# Buying date is missing: inserting it as default date for row 449
# Buying date is missing: inserting it as default date for row 450
# Buying date is missing: inserting it as default date for row 451
# Buying date is missing: inserting it as default date for row 452
# Buying date is missing: inserting it as default date for row 453
# Buying date is missing: inserting it as default date for row 454
# Buying date is missing: inserting it as default date for row 455
# Buying date is missing: inserting it as default date for row 456
# Buying date is missing: inserting it as default date for row 457
# Buying date is missing: inserting it as default date for row 458
# Buying date is missing: inserting it as default date for row 459
# Buying date is missing: inserting it as default date for row 460
# Buying date is missing: inserting it as default date for row 461
# Buying date is missing: inserting it as default date for row 462
# Buying date is missing: inserting it as default date for row 463
# Buying date is missing: inserting it as default date for row 464
# Buying date is missing: inserting it as default date for row 465
# Buying date is missing: inserting it as default date for row 466
# Buying date is missing: inserting it as default date for row 467
# Buying date is missing: inserting it as default date for row 468
# Buying date is missing: inserting it as default date for row 469
# Buying date is missing: inserting it as default date for row 470
# Buying date is missing: inserting it as default date for row 471
# Buying date is missing: inserting it as default date for row 472
# Buying date is missing: inserting it as default date for row 473
# Buying date is missing: inserting it as selling date for row 474
# Buying date is missing: inserting it as selling date for row 475
# Buying date is missing: inserting it as selling date for row 476
# Buying date is missing: inserting it as selling date for row 477
# Buying date is missing: inserting it as default date for row 478
# Buying date is missing: inserting it as selling date for row 479
# Buying date is missing: inserting it as selling date for row 480
# Buying date is missing: inserting it as default date for row 481
# Buying date is missing: inserting it as selling date for row 482
# Buying date is missing: inserting it as selling date for row 483
# Buying date is missing: inserting it as selling date for row 484
# Buying date is missing: inserting it as selling date for row 485
# Buying date is missing: inserting it as selling date for row 486
# Buying date is missing: inserting it as selling date for row 487
# Buying date is missing: inserting it as selling date for row 488
# Buying date is missing: inserting it as selling date for row 489
# Buying date is missing: inserting it as selling date for row 490
# Buying date is missing: inserting it as selling date for row 491
# Buying date is missing: inserting it as selling date for row 492
# Buying date is missing: inserting it as selling date for row 493
# Buying date is missing: inserting it as default date for row 494
# Buying date is missing: inserting it as selling date for row 495
# Buying date is missing: inserting it as default date for row 496
# Buying date is missing: inserting it as selling date for row 497
# Buying date is missing: inserting it as selling date for row 498
# Buying date is missing: inserting it as selling date for row 499
# Buying date is missing: inserting it as selling date for row 500
# Buying date is missing: inserting it as selling date for row 501
# Buying date is missing: inserting it as selling date for row 502
# Buying date is missing: inserting it as default date for row 503
# Buying date is missing: inserting it as selling date for row 504
# Buying date is missing: inserting it as selling date for row 505
# Buying date is missing: inserting it as default date for row 506
# Buying date is missing: inserting it as default date for row 507
# Buying date is missing: inserting it as default date for row 508
# Buying date is missing: inserting it as default date for row 509
# Buying date is missing: inserting it as default date for row 510
# Buying date is missing: inserting it as default date for row 511
# Buying date is missing: inserting it as default date for row 512
# Buying date is missing: inserting it as default date for row 513
# Buying date is missing: inserting it as default date for row 514
# Buying date is missing: inserting it as default date for row 515
# Buying date is missing: inserting it as default date for row 516
# Buying date is missing: inserting it as default date for row 517
# Buying date is missing: inserting it as default date for row 518
# Buying date is missing: inserting it as default date for row 519
# Buying date is missing: inserting it as default date for row 520
# Buying date is missing: inserting it as selling date for row 521
# Buying date is missing: inserting it as selling date for row 522
# Buying date is missing: inserting it as selling date for row 523
# Buying date is missing: inserting it as selling date for row 524
# Buying date is missing: inserting it as selling date for row 525
# Buying date is missing: inserting it as default date for row 526
# Buying date is missing: inserting it as selling date for row 527
# Buying date is missing: inserting it as selling date for row 528
# Buying date is missing: inserting it as selling date for row 529
# Buying date is missing: inserting it as selling date for row 530
# Buying date is missing: inserting it as selling date for row 531
# Buying date is missing: inserting it as selling date for row 532
# Buying date is missing: inserting it as selling date for row 533
# Buying date is missing: inserting it as selling date for row 534
# Buying date is missing: inserting it as selling date for row 535
# Buying date is missing: inserting it as selling date for row 536
# Buying date is missing: inserting it as default date for row 537
# Buying date is missing: inserting it as default date for row 538
# Buying date is missing: inserting it as default date for row 539
# Buying date is missing: inserting it as selling date for row 540
# Buying date is missing: inserting it as selling date for row 541
# Buying date is missing: inserting it as default date for row 542
# Buying date is missing: inserting it as default date for row 543
# Buying date is missing: inserting it as default date for row 544
# Buying date is missing: inserting it as default date for row 545
# Buying date is missing: inserting it as default date for row 546
# Buying date is missing: inserting it as default date for row 547
# Buying date is missing: inserting it as default date for row 548
# Buying date is missing: inserting it as default date for row 549
# Buying date is missing: inserting it as default date for row 550
# Buying date is missing: inserting it as default date for row 551
# Buying date is missing: inserting it as default date for row 552
# Buying date is missing: inserting it as default date for row 553
# Buying date is missing: inserting it as default date for row 554
# Buying date is missing: inserting it as default date for row 555
# Buying date is missing: inserting it as default date for row 556
# Buying date is missing: inserting it as default date for row 557
# Buying date is missing: inserting it as default date for row 558
# Buying date is missing: inserting it as default date for row 559
# Buying date is missing: inserting it as default date for row 560
# Buying date is missing: inserting it as default date for row 561
# Buying date is missing: inserting it as default date for row 562
# Buying date is missing: inserting it as default date for row 563
# Buying date is missing: inserting it as default date for row 564
# Buying date is missing: inserting it as default date for row 565
# Buying date is missing: inserting it as default date for row 566
# Buying date is missing: inserting it as default date for row 567
# Buying date is missing: inserting it as default date for row 568
# Buying date is missing: inserting it as default date for row 569
# Buying date is missing: inserting it as default date for row 570
# Buying date is missing: inserting it as selling date for row 571
# Buying date is missing: inserting it as selling date for row 572
# Buying date is missing: inserting it as default date for row 573
# Buying date is missing: inserting it as selling date for row 574
# Buying date is missing: inserting it as selling date for row 575
# Buying date is missing: inserting it as default date for row 576
# Buying date is missing: inserting it as selling date for row 577
# Buying date is missing: inserting it as selling date for row 578
# Buying date is missing: inserting it as default date for row 579
# Buying date is missing: inserting it as default date for row 580
# Buying date is missing: inserting it as default date for row 581
# Buying date is missing: inserting it as selling date for row 582
# Buying date is missing: inserting it as selling date for row 583
# Buying date is missing: inserting it as default date for row 584
# Buying date is missing: inserting it as default date for row 585
# Buying date is missing: inserting it as default date for row 586
# Buying date is missing: inserting it as default date for row 587
# Buying date is missing: inserting it as default date for row 588
# Buying date is missing: inserting it as default date for row 589
# Buying date is missing: inserting it as default date for row 590
# Buying date is missing: inserting it as default date for row 591
# Buying date is missing: inserting it as default date for row 592
# Buying date is missing: inserting it as default date for row 593
# Buying date is missing: inserting it as default date for row 594
# Buying date is missing: inserting it as default date for row 595
# Buying date is missing: inserting it as default date for row 596
# Buying date is missing: inserting it as default date for row 597
# Buying date is missing: inserting it as default date for row 598
# Buying date is missing: inserting it as default date for row 599
# Buying date is missing: inserting it as default date for row 600
# Buying date is missing: inserting it as default date for row 601
# Buying date is missing: inserting it as default date for row 602
# Buying date is missing: inserting it as default date for row 603
# Buying date is missing: inserting it as default date for row 604
# Buying date is missing: inserting it as default date for row 605
# Buying date is missing: inserting it as default date for row 606
# Buying date is missing: inserting it as default date for row 607
# Buying date is missing: inserting it as default date for row 608
# Buying date is missing: inserting it as default date for row 609
# Buying date is missing: inserting it as default date for row 610
# Buying date is missing: inserting it as default date for row 611
# Buying date is missing: inserting it as default date for row 612
# Buying date is missing: inserting it as default date for row 613
# Buying date is missing: inserting it as default date for row 614
# Buying date is missing: inserting it as default date for row 615
# Buying date is missing: inserting it as default date for row 616
# Buying date is missing: inserting it as default date for row 617
# Buying date is missing: inserting it as default date for row 618
# Buying date is missing: inserting it as default date for row 619
# Buying date is missing: inserting it as default date for row 620
# Buying date is missing: inserting it as default date for row 621
# Buying date is missing: inserting it as default date for row 622
# Buying date is missing: inserting it as default date for row 623
# Buying date is missing: inserting it as default date for row 624
# Buying date is missing: inserting it as default date for row 625
# Buying date is missing: inserting it as default date for row 626
# Buying date is missing: inserting it as default date for row 627
# Buying date is missing: inserting it as default date for row 628
# Buying date is missing: inserting it as default date for row 629
# Buying date is missing: inserting it as default date for row 630
# Buying date is missing: inserting it as default date for row 631
# Buying date is missing: inserting it as default date for row 632
# Buying date is missing: inserting it as default date for row 633
# Buying date is missing: inserting it as default date for row 634
# Buying date is missing: inserting it as default date for row 635
# Buying date is missing: inserting it as default date for row 636
# Buying date is missing: inserting it as default date for row 637
# Buying date is missing: inserting it as default date for row 638
# Buying date is missing: inserting it as default date for row 639
# Buying date is missing: inserting it as default date for row 640
# Buying date is missing: inserting it as default date for row 641
# Buying date is missing: inserting it as selling date for row 642
# Buying date is missing: inserting it as selling date for row 643
# Buying date is missing: inserting it as default date for row 644
# Buying date is missing: inserting it as selling date for row 645
# Buying date is missing: inserting it as default date for row 646
# Buying date is missing: inserting it as default date for row 647
# Buying date is missing: inserting it as default date for row 648
# Buying date is missing: inserting it as default date for row 649
# Buying date is missing: inserting it as default date for row 650
# Buying date is missing: inserting it as default date for row 651
# Buying date is missing: inserting it as default date for row 652
# Buying date is missing: inserting it as default date for row 653

# %%
import pandas as pd

df = pd.read_csv(data_path)
df = df.drop(columns = ['date_comment'])
df.to_csv(data_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 4
#       1 import pandas as pd
#       3 df = pd.read_csv(data_path)
# ----> 4 df = df.drop(columns = ['date_comment'])
#       5 df.to_csv(data_path, index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['date_comment'] not found in axis"
