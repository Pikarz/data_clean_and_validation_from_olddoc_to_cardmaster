# %% [markdown]
# <a href="https://colab.research.google.com/github/Pikarz/data_clean_and_validation_from_olddoc_to_cardmaster/blob/main/05%20-%20insert_corrected_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Insert the data
# This notebook aims to insert the corrected data into the database. It takes in input the output of the notebook 04 and inserts each row that didn't generate errors in the previous notebooks.
#
# The notebook also makes additional errors checks that should have already been made by the pipeline, just to be sure that the inserted data is correct.

# %%
import pandas as pd
import psycopg2
from datetime import datetime, time

def get_datetime(str_date: str) -> datetime:
    date = None
    try:
        date = datetime.strptime(str_date, "%Y-%m-%d").replace(hour=0, minute=0, second=0)
    except ValueError:
        date = datetime.strptime(str_date, "%Y-%m-%d %H:%M:%S")
    return date

def create_selling_card(curr, card, s_date):
  query = "INSERT INTO SellingCollectable (collectable, date) VALUES (%s, %s) RETURNING collectable"
  try:
    curr.execute(query, (card, s_date))
    selling_card = curr.fetchone()
    if selling_card:
      print("Selling card inserted successfully")
    return selling_card
  except psycopg2.DatabaseError as e:
    print(f"Error while inserting a selling row: {e}")
    return None

def create_disposed_card(curr, card, selling_date, s_price):
  s_date = get_datetime(selling_date)
  buyer_name = 'default_counterparty'

  # Create a selling card record
  selling_card = create_selling_card(curr, card, s_date)
  if pd.isna(selling_card):
    return None

  source_id = get_or_insert_source(curr, buyer_name)
  counterparty_id = get_or_insert_counterparty(curr, buyer_name)

  # Insert a transaction record and get its ID
  transaction_query = "INSERT INTO CollectableTransaction (date, source, counterparty) VALUES (%s, %s, %s) RETURNING id"
  transaction = None
  try:
    curr.execute(transaction_query, (s_date, source_id, counterparty_id,))
    transaction = curr.fetchone()
  except psycopg2.DatabaseError as e:
    return None
  if transaction is None:
    return None
  # Insert the disposed card record
  disposed_query = "INSERT INTO disposedCollectable (collectable, transaction, amount_received) VALUES (%s, %s, %s) RETURNING collectable"
  try:
    curr.execute(disposed_query, (card, transaction, s_price,))
    disposed_collectable = curr.fetchone()
    if disposed_collectable:
      print("Disposed card inserted successfully")
    return disposed_collectable
  except psycopg2.DatabaseError as e:
    return None

def create_acquired_card(curr, card, transaction, purchase_amount, shipping_costs='0', tax_costs='0'):
  query = "INSERT INTO acquiredCollectable (collectable, transaction, purchase_amount, shipping_costs, tax_costs) VALUES (%s, %s, %s, %s, %s) RETURNING collectable"
  try:
    curr.execute(query,(card, transaction, purchase_amount, shipping_costs, tax_costs))
    acquired_card = curr.fetchone()[0]
    if acquired_card:
      print('Acquired card inserted successfully')
    return acquired_card
  except Exception as e:
    return None

def get_or_insert_source(curr, source_name):
    source_id = None
    if pd.isna(source_name):
      source_name = 'default_counterparty'
    curr.execute("SELECT name FROM Source WHERE name = %s", (source_name,)) # check if it exists
    source_id = curr.fetchone()

    if source_id is None:
      curr.execute("INSERT INTO Source (name) VALUES (%s) RETURNING name", (source_name,)) # insert if it doesn't exist
      source_id = curr.fetchone()[0]
    return source_id

def get_or_insert_counterparty(curr, counterparty_name):
  counterparty_id = None
  if pd.isna(counterparty_name):
    counterparty_name = 'default_counteparty'
  curr.execute("SELECT name FROM Counterparty WHERE name = %s", (counterparty_name,)) # check if it exists
  counterparty_id = curr.fetchone()

  if counterparty_id is None:
    curr.execute("INSERT INTO Counterparty (name) VALUES (%s) RETURNING name", (counterparty_name,)) # insert if it doesn't exist
    counterparty_id = curr.fetchone()[0]
  return counterparty_id

def get_or_create_buying_transaction(curr, cached_transactions, b_date, counterparty_name, source):
  try: # cache hit
    transaction = cached_transactions[(b_date, counterparty_name)]
    return transaction, cached_transactions
  except KeyError: # cache miss
    source_id = get_or_insert_source(curr, source) # get source
    counterparty_id = get_or_insert_counterparty(curr, counterparty_name) #get counterparty
    if source_id is None or counterparty_id is None:
      return None, cached_transactions
    try:
      curr.execute("INSERT INTO CollectableTransaction (date, source, counterparty) VALUES (%s, %s, %s) RETURNING id", (b_date, source_id, counterparty_id,))
      transaction_id = curr.fetchone()
      # add to the cached transaction
      cached_transactions[(b_date, counterparty_name)] = transaction_id
      if transaction_id:
        print("Transaction inserted successfully")
      return transaction_id, cached_transactions
    except Exception as e:
      conn.rollback()
      return None, cached_transactions

def create_card_instance(curr, expansion, number, date_acquired, condition, language, in_collection, version, inked, comment):
  if condition == 'NM+':
    condition = 'MT'
  try:
    query_collectable = """
      INSERT INTO Collectable (in_collection, date_acquired, is_arrived, comment) VALUES (%s, %s, %s, %s) RETURNING id
    """
    curr.execute(query_collectable, (in_collection, date_acquired, True, comment))
    collectable_id = curr.fetchone()[0]
    query_cardinstance = """
      INSERT INTO CardInstance (card, cardtype_number, cardtype_expansion, language, condition, version, inked)
      VALUES (%s, %s, %s, %s, %s, %s, %s) RETURNING card
    """
    curr.execute(query_cardinstance, (collectable_id, number, expansion, language, condition, version, inked))
    card = curr.fetchone()
    if card is not None:
      print(f"CardInstance ({expansion}, {number}, {version}) inserted successfully.")
  except Exception as e:
    print(f"Exception while inserting a CardInstance: {e}")
  finally:
    return card

def get_actual_expansion(curr, expansion, number):
  actual_expansion=None
  query = """
          SELECT CardType.expansion
          FROM CardType
          WHERE CardType.expansion = %s AND CardType.number = %s
    """
  curr.execute(query, (expansion, number,))
  result = curr.fetchone()
  if result: # the expansion is a main one
    actual_expansion = result
  else:      # sub expansion
      query = """
        SELECT Cardexpansion.id
        FROM CardType, Cardexpansion
        WHERE Cardexpansion.super_expansion = %s
        AND CardType.expansion = Cardexpansion.id
        AND CardType.number = %s
      """
      curr.execute(query, (expansion, number,))
      result = curr.fetchone()
      if result:
        actual_expansion = result
  if actual_expansion:
    return actual_expansion[0]
  return None

def check_card_consistency(curr, expansion, number, version):
  query = """
    SELECT 1
    FROM versioncardtype
    WHERE card_expansion=%s
    AND card_number=%s
    AND version=%s
  """
  curr.execute(query, (expansion, number, version,))
  versioncardtype = curr.fetchone()
  return versioncardtype is not None # false when the combination exists

def insert_corrected_data(db_params, data_path):
  input_check = input("Did you run check_date_consistency(), fix_names_inconsistencies() and insert_version()?")
  if input_check.lower() != 'y':
    return
  conn = None
  curr = None
  try:
    conn = psycopg2.connect(**db_params)
    curr = conn.cursor()
  except Exception as e:
    print(f"Error while connecting to the DB: {e}")
    return

  df = pd.read_csv(data_path)
  if 'inserted' not in df.columns:
    df['inserted'] = False
    df['insert_comment'] = ''
    df.to_csv(data_path, index=False)

  cached_transactions = {} # cache to store transactions so that it's possible to deduce, given the date and the counterparty, a transaction
  for i, row in df.iterrows():
    if  row['date_comment'] != 'OK' or \
        row['language_comment'] != 'OK' or \
        row['status_name'] != 0 or \
        pd.isna(row['version']) or \
        row['version']=='ERROR_VERSION' or \
        row['inserted']=='TRUE': # unprocessed, erroneous or already inserted row
        continue

    result_msg = 'Inserted\n' # final message that will be displayed in the comments if all goes well

    # all the data of a card
    date_acquired = row['B-Date']
    if pd.isna(date_acquired):
      date_acquired = '2020-01-01' # handle missing information by setting a default value
    number = str(row['#'])
    actual_expansion = get_actual_expansion(curr, row['Set'], number) # to handle sub-expansions
    version = row['version']
    condition = row['Condition']
    if condition == 'M':
      condition = 'MT'
    if pd.isna(condition):
      print(f"ERROR: the card at row {i} has no condition")
      df.at[i, 'insert_comment'] = 'ERROR: The card has no condition'
      df.to_csv(data_path, index=False)
      continue
    language = row['Lang']
    in_collection = row['in collection']
    comment = row['Comments']
    inked = False
    if pd.notna(comment): # check inked status
      inked = 'inked' in comment.lower()
      # Remove 'inked' from comments
      comment = comment.lower().replace('inked', '').strip()

    if inked and condition != 'PO': # do not add cards that are stated as inked but their state is not poor
      print(f'ERROR: The card at row {i} is inked but its condition is not "PO"')
      df.at[i, 'insert_comment'] = 'ERROR: The card has inked in its comment but its condition is not PO'
      df.to_csv(data_path, index=False)
      continue

    check_card = check_card_consistency(curr, actual_expansion, number, version)
    if not check_card:
      print(f"Error! The card at row {i} has a combination of (set: {actual_expansion}, number: {number}, version: {version}) that doesn't exist in the DB.")
      df.at[i, 'insert_comment'] = 'ERROR: The (set, number, version) does not exist'
      df.to_csv(data_path, index=False)
      continue
    result_msg += 'Card checked\n'

    card = create_card_instance(curr, actual_expansion, number, date_acquired, condition, language, in_collection, version, inked, comment)
    if card is None:
      print(f"Error! An error occurred while inserting a card!")
      df.at[i, 'insert_comment'] = 'ERROR: an error occurred while inserting'
      df.to_csv(data_path, index=False)
      conn.rollback()
      continue

    result_msg += 'inserted\n'

    buying_price = row['B-Price']
    if not pd.isna(buying_price):
      seller = row['seller']
      source = row['source']
      transaction, cached_transactions = get_or_create_buying_transaction(curr, cached_transactions, date_acquired, seller, source)
      if pd.isna(transaction):
        df.at[i, 'insert_comment'] = 'ERROR: The card was inserted but while inserting its buying transaction an error occurred.'
        df.to_csv(data_path, index=False)
        conn.rollback()
        continue
      result_msg += 'buying transaction created\n'
      acquired_card = create_acquired_card(curr, card, transaction, buying_price)
      if acquired_card is None:
        df.at[i, 'insert_comment'] = 'ERROR: The transaction was inserted but an error occurred while inserting the acquired card.'
        df.to_csv(data_path, index=False)
        conn.rollback()
        continue
      result_msg += 'acquired_card created\n'

    selling_price = row['S-Price']
    selling_date = row['S-Date']
    if not pd.isna(selling_date) or not pd.isna(selling_price): # if one exists
      if not (pd.notna(selling_date) == pd.notna(selling_price)): # if one is missing then there's an error (either both or none)
        print("ERROR! Selling date or selling price is missing")
        df.at[i, 'insert_comment'] = 'ERROR: Missing selling date or selling price'
        df.to_csv(data_path, index=False)
        conn.rollback()
        continue
      result_msg += 'selling card inserted\n'

      disposed_card = create_disposed_card(curr, card, selling_date, selling_price)
      if disposed_card is None:
        print("ERROR! An error occurred while inserting a selling or disposed card")
        df.at[i, 'insert_comment'] = 'ERROR: An error occurred while inserting a selling or disposed card'
        df.to_csv(data_path, index=False)
        conn.rollback()
        continue
      else:
        result_msg += 'disposed card inserted\n'
    result_msg += 'Done!\n'
    df.at[i, 'inserted'] = True
    df.at[i,'insert_comment'] = result_msg
    df.to_csv(data_path, index=False)
    conn.commit()
  curr.close()
  print("### Completed! ###")

# %%
data_path = 'H:/My Drive/pkmn/pok_swap.csv'

db_params = {
    'host': '192.168.example.example',
    'port': '5432',
    'database': 'cardmaster',
    'user': 'example',
    'password': 'example'
}

insert_corrected_data(db_params, data_path)
# Out:
# Did you run check_date_consistency(), fix_names_inconsistencies() and insert_version()?y
# CardInstance (BS, 16, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (BS, 10, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 94, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GH, 60, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GH, 62, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GH, 63, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 67, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 84, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 112, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 39, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GC, 69, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 80, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 90, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 104, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 107, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 108, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 65, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 119, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (AQ, 83, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 91, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 112, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 143, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (LOT, 154, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GC, 86, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 88, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 95, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 75, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 83, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 27, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 41, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 58, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 68, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DX, 47, Reverse Holo) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (EX, 51, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 94, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 37, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (FCO, 73, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (HL, 72, Reverse Holo) inserted successfully.
# Acquired card inserted successfully
# CardInstance (CIN, 38, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (UD, 53, Reverse Holo) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GC, 12, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 75, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 98, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 122, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 79, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 96, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 68, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 87, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 79, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 96, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 110, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 121, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 57, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 56, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (TRR, 64, Reverse Holo) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GH, 98, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 48, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 53, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 74, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 88, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 89, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 95, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 102, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 70, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 93, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 97, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 131, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 89, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 111, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 114, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 129, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 62, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 131, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DS, 108, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GH, 106, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 37, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 47, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 52, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 77, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 90, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 93, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 110, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 121, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 53, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 72, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 82, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 83, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 89, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 91, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 94, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DX, 74, Reverse Holo) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 15, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 36, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 33, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 46, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 92, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 105, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 138, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 142, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 41, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 117, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 110, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (BS, 17, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (JU, 16, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GH, 59, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 104, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 56, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 71, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 86, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 91, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 97, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 109, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 122, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (TR, 14, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 16, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 32, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 57, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 92, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 100, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DRV, 9, Stamped Promo) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 88, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (NR, 60, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 59, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 58, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 63, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 54, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 75, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 78, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 102, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 103, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 97, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 107, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 120, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 109, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 126, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 145, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 147, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 53, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 82, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 84, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 90, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 128, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 53, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 62, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 43, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 61, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 156, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (UF, 43, Reverse Holo) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (GH, 77, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DF, 7, Reverse Holo) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (BS, 1, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (UL, 89, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (FL, 44, Reverse Holo) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 130, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 34, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 38, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 55, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 58, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 72, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 79, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 87, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 115, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 117, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 125, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 126, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 127, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 31, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 33, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 38, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 44, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 55, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 56, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 59, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 62, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 64, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 73, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 74, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 78, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 85, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 95, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 128, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DRV, 11, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 64, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 80, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 93, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 104, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 141, Reverse Holo) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 134, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 155, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 157, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 153, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 96, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 107, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 149, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 18, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (JU, 15, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (FO, 6, First Edition) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (FO, 10, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (HL, 61, Reverse Holo) inserted successfully.
# Acquired card inserted successfully
# CardInstance (PLB, 93, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 28, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 57, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 100, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 51, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 73, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 94, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 21, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 22, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 28, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 66, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 77, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 103, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 106, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 120, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 6, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 72, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 99, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 118, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 125, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 76, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 94, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 111, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 147, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 47, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 52, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 44, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 46, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 42, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 45, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 40, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 39, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 50, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 33, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 35, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 30, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 51, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 38, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 37, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 29, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 28, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 32, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 55, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 31, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NR, 41, First Edition) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GC, 51, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GH, 107, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 88, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (BS, 21, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (BS, 14, First Edition) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (NDI, 37, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 38, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 40, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 42, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 43, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 45, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 46, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 49, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 51, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 52, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 53, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 54, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 55, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 56, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 57, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 61, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 63, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 65, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 66, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 67, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 69, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 71, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NDI, 72, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 26, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 27, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 29, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 34, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 35, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 36, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 38, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 39, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 41, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 42, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 43, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 47, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 49, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 51, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 53, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 54, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 55, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 59, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 60, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 62, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 64, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 65, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 68, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 70, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 71, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 72, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 73, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 74, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 75, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 79, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 80, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 81, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 82, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 92, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 94, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 95, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 97, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 100, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 102, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 106, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 107, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 109, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (NG, 111, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (GRI, 38, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (BS, 42, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 45, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DRV, 8, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (EVO, 24, Reverse Holo) inserted successfully.
# Acquired card inserted successfully
# CardInstance (DR, 93, default) inserted successfully.
# Transaction inserted successfully
# Acquired card inserted successfully
# CardInstance (AQ, 24, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 54, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 80, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (AQ, 108, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 124, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (EX, 130, default) inserted successfully.
# Acquired card inserted successfully
# CardInstance (BS, 16, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (BS, 10, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 94, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 60, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 62, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 63, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 67, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 84, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 112, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 39, default) inserted successfully.
# CardInstance (GC, 69, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 80, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 90, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 104, default) inserted successfully.
# CardInstance (GC, 107, default) inserted successfully.
# CardInstance (GC, 108, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 65, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (EX, 119, default) inserted successfully.
# CardInstance (AQ, 83, default) inserted successfully.
# CardInstance (AQ, 91, default) inserted successfully.
# CardInstance (AQ, 112, default) inserted successfully.
# CardInstance (EX, 143, default) inserted successfully.
# CardInstance (LOT, 154, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 86, default) inserted successfully.
# CardInstance (GC, 88, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (EX, 95, default) inserted successfully.
# CardInstance (GH, 75, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 83, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 27, default) inserted successfully.
# CardInstance (GC, 41, default) inserted successfully.
# CardInstance (GC, 58, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 68, default) inserted successfully.
# CardInstance (DX, 47, Reverse Holo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (EX, 51, default) inserted successfully.
# CardInstance (EX, 94, default) inserted successfully.
# CardInstance (EX, 37, default) inserted successfully.
# CardInstance (FCO, 73, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (HL, 72, Reverse Holo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (CIN, 38, default) inserted successfully.
# CardInstance (UD, 53, Reverse Holo) inserted successfully.
# CardInstance (GC, 12, default) inserted successfully.
# CardInstance (GC, 75, default) inserted successfully.
# CardInstance (GC, 98, default) inserted successfully.
# CardInstance (GC, 122, default) inserted successfully.
# CardInstance (GC, 79, default) inserted successfully.
# CardInstance (GC, 96, default) inserted successfully.
# CardInstance (EX, 68, default) inserted successfully.
# CardInstance (EX, 87, default) inserted successfully.
# CardInstance (EX, 79, default) inserted successfully.
# CardInstance (EX, 96, default) inserted successfully.
# CardInstance (EX, 110, default) inserted successfully.
# CardInstance (EX, 121, default) inserted successfully.
# CardInstance (NR, 57, First Edition) inserted successfully.
# CardInstance (NR, 56, First Edition) inserted successfully.
# CardInstance (TRR, 64, Reverse Holo) inserted successfully.
# CardInstance (GH, 98, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 48, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 53, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 74, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 88, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 89, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 95, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 102, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 70, default) inserted successfully.
# CardInstance (GC, 93, default) inserted successfully.
# CardInstance (GC, 97, default) inserted successfully.
# CardInstance (GC, 131, default) inserted successfully.
# CardInstance (EX, 89, default) inserted successfully.
# CardInstance (EX, 111, default) inserted successfully.
# CardInstance (EX, 114, default) inserted successfully.
# CardInstance (EX, 129, default) inserted successfully.
# CardInstance (AQ, 62, default) inserted successfully.
# CardInstance (AQ, 131, default) inserted successfully.
# CardInstance (DS, 108, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 106, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 37, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 47, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 52, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 77, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 90, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 93, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 110, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 121, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 53, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 72, default) inserted successfully.
# CardInstance (GC, 82, default) inserted successfully.
# CardInstance (GC, 83, default) inserted successfully.
# CardInstance (GC, 89, default) inserted successfully.
# CardInstance (GC, 91, default) inserted successfully.
# CardInstance (GC, 94, default) inserted successfully.
# CardInstance (DX, 74, Reverse Holo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NR, 15, default) inserted successfully.
# CardInstance (NR, 36, default) inserted successfully.
# CardInstance (EX, 33, default) inserted successfully.
# CardInstance (EX, 46, default) inserted successfully.
# CardInstance (EX, 92, default) inserted successfully.
# CardInstance (EX, 105, default) inserted successfully.
# CardInstance (EX, 138, default) inserted successfully.
# CardInstance (EX, 142, default) inserted successfully.
# CardInstance (AQ, 41, default) inserted successfully.
# CardInstance (AQ, 117, default) inserted successfully.
# CardInstance (AQ, 110, default) inserted successfully.
# CardInstance (BS, 17, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (JU, 16, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 59, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 104, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 56, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 71, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 86, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 91, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 97, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 109, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 122, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (TR, 14, default) inserted successfully.
# CardInstance (GC, 16, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 32, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 57, default) inserted successfully.
# CardInstance (GC, 92, default) inserted successfully.
# CardInstance (GC, 100, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (DRV, 9, Stamped Promo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NG, 88, default) inserted successfully.
# CardInstance (NR, 60, default) inserted successfully.
# CardInstance (NR, 59, default) inserted successfully.
# CardInstance (NR, 58, default) inserted successfully.
# CardInstance (NR, 63, First Edition) inserted successfully.
# CardInstance (NR, 54, default) inserted successfully.
# CardInstance (EX, 75, default) inserted successfully.
# CardInstance (EX, 78, default) inserted successfully.
# CardInstance (EX, 102, default) inserted successfully.
# CardInstance (EX, 103, default) inserted successfully.
# CardInstance (EX, 97, default) inserted successfully.
# CardInstance (EX, 107, default) inserted successfully.
# CardInstance (EX, 120, default) inserted successfully.
# CardInstance (EX, 109, default) inserted successfully.
# CardInstance (EX, 126, default) inserted successfully.
# CardInstance (EX, 145, default) inserted successfully.
# CardInstance (EX, 147, default) inserted successfully.
# CardInstance (AQ, 53, default) inserted successfully.
# CardInstance (AQ, 82, default) inserted successfully.
# CardInstance (AQ, 84, default) inserted successfully.
# CardInstance (AQ, 90, default) inserted successfully.
# CardInstance (AQ, 128, default) inserted successfully.
# CardInstance (NR, 53, First Edition) inserted successfully.
# CardInstance (NR, 62, First Edition) inserted successfully.
# CardInstance (EX, 43, default) inserted successfully.
# CardInstance (EX, 61, default) inserted successfully.
# CardInstance (EX, 156, default) inserted successfully.
# CardInstance (UF, 43, Reverse Holo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 77, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (DF, 7, Reverse Holo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (BS, 1, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (UL, 89, default) inserted successfully.
# CardInstance (FL, 44, Reverse Holo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 130, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 34, default) inserted successfully.
# CardInstance (GH, 38, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 55, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 58, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 72, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 79, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 87, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 115, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 117, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 125, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 126, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 127, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 31, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 33, default) inserted successfully.
# CardInstance (GC, 38, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 44, default) inserted successfully.
# CardInstance (GC, 55, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 56, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 59, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 62, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 64, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 73, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 74, default) inserted successfully.
# CardInstance (GC, 78, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 85, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 95, default) inserted successfully.
# CardInstance (GC, 128, default) inserted successfully.
# CardInstance (DRV, 11, default) inserted successfully.
# CardInstance (NR, 64, default) inserted successfully.
# CardInstance (EX, 80, default) inserted successfully.
# CardInstance (EX, 93, default) inserted successfully.
# CardInstance (EX, 104, default) inserted successfully.
# CardInstance (EX, 141, Reverse Holo) inserted successfully.
# CardInstance (EX, 134, default) inserted successfully.
# CardInstance (EX, 155, default) inserted successfully.
# CardInstance (EX, 157, default) inserted successfully.
# CardInstance (EX, 153, default) inserted successfully.
# CardInstance (AQ, 96, default) inserted successfully.
# CardInstance (AQ, 107, default) inserted successfully.
# CardInstance (EX, 149, default) inserted successfully.
# CardInstance (NR, 18, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (JU, 15, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (FO, 6, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (FO, 10, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (HL, 61, Reverse Holo) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (PLB, 93, default) inserted successfully.
# CardInstance (GH, 28, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 57, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 100, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 51, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 73, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 94, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 21, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 22, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 28, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 66, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GC, 77, default) inserted successfully.
# CardInstance (GC, 103, default) inserted successfully.
# CardInstance (GC, 106, default) inserted successfully.
# CardInstance (GC, 120, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NDI, 6, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (EX, 72, default) inserted successfully.
# CardInstance (EX, 99, default) inserted successfully.
# CardInstance (EX, 118, default) inserted successfully.
# CardInstance (EX, 125, default) inserted successfully.
# CardInstance (AQ, 76, default) inserted successfully.
# CardInstance (AQ, 94, default) inserted successfully.
# CardInstance (AQ, 111, default) inserted successfully.
# CardInstance (AQ, 147, default) inserted successfully.
# CardInstance (NR, 47, default) inserted successfully.
# CardInstance (NR, 52, default) inserted successfully.
# CardInstance (NR, 44, First Edition) inserted successfully.
# CardInstance (NR, 46, First Edition) inserted successfully.
# CardInstance (NR, 42, First Edition) inserted successfully.
# CardInstance (NR, 45, default) inserted successfully.
# CardInstance (NR, 40, default) inserted successfully.
# CardInstance (NR, 39, First Edition) inserted successfully.
# CardInstance (NR, 50, First Edition) inserted successfully.
# CardInstance (NR, 33, First Edition) inserted successfully.
# CardInstance (NR, 35, default) inserted successfully.
# CardInstance (NR, 30, First Edition) inserted successfully.
# CardInstance (NR, 51, First Edition) inserted successfully.
# CardInstance (NR, 38, default) inserted successfully.
# CardInstance (NR, 37, default) inserted successfully.
# CardInstance (NR, 29, default) inserted successfully.
# CardInstance (NR, 28, default) inserted successfully.
# CardInstance (NR, 32, default) inserted successfully.
# CardInstance (NR, 55, default) inserted successfully.
# CardInstance (NR, 31, First Edition) inserted successfully.
# CardInstance (NR, 41, First Edition) inserted successfully.
# CardInstance (GC, 51, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (GH, 107, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (AQ, 88, default) inserted successfully.
# CardInstance (BS, 21, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (BS, 14, First Edition) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NDI, 37, default) inserted successfully.
# CardInstance (NDI, 38, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NDI, 40, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NDI, 42, default) inserted successfully.
# CardInstance (NDI, 43, default) inserted successfully.
# CardInstance (NDI, 45, default) inserted successfully.
# CardInstance (NDI, 46, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NDI, 49, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (NDI, 51, default) inserted successfully.
# CardInstance (NDI, 52, default) inserted successfully.
# CardInstance (NDI, 53, default) inserted successfully.
# CardInstance (NDI, 54, default) inserted successfully.
# CardInstance (NDI, 55, default) inserted successfully.
# CardInstance (NDI, 56, default) inserted successfully.
# CardInstance (NDI, 57, default) inserted successfully.
# CardInstance (NDI, 61, default) inserted successfully.
# CardInstance (NDI, 63, default) inserted successfully.
# CardInstance (NDI, 65, default) inserted successfully.
# CardInstance (NDI, 66, default) inserted successfully.
# CardInstance (NDI, 67, default) inserted successfully.
# CardInstance (NDI, 69, default) inserted successfully.
# CardInstance (NDI, 71, default) inserted successfully.
# CardInstance (NDI, 72, default) inserted successfully.
# CardInstance (NG, 26, default) inserted successfully.
# CardInstance (NG, 27, default) inserted successfully.
# CardInstance (NG, 29, default) inserted successfully.
# CardInstance (NG, 34, default) inserted successfully.
# CardInstance (NG, 35, default) inserted successfully.
# CardInstance (NG, 36, default) inserted successfully.
# CardInstance (NG, 38, default) inserted successfully.
# CardInstance (NG, 39, default) inserted successfully.
# CardInstance (NG, 41, default) inserted successfully.
# CardInstance (NG, 42, default) inserted successfully.
# CardInstance (NG, 43, default) inserted successfully.
# CardInstance (NG, 47, default) inserted successfully.
# CardInstance (NG, 49, default) inserted successfully.
# CardInstance (NG, 51, default) inserted successfully.
# CardInstance (NG, 53, default) inserted successfully.
# CardInstance (NG, 54, default) inserted successfully.
# CardInstance (NG, 55, default) inserted successfully.
# CardInstance (NG, 59, default) inserted successfully.
# CardInstance (NG, 60, default) inserted successfully.
# CardInstance (NG, 62, default) inserted successfully.
# CardInstance (NG, 64, default) inserted successfully.
# CardInstance (NG, 65, default) inserted successfully.
# CardInstance (NG, 68, default) inserted successfully.
# CardInstance (NG, 70, default) inserted successfully.
# CardInstance (NG, 71, default) inserted successfully.
# CardInstance (NG, 72, default) inserted successfully.
# CardInstance (NG, 73, default) inserted successfully.
# CardInstance (NG, 74, default) inserted successfully.
# CardInstance (NG, 75, default) inserted successfully.
# CardInstance (NG, 79, default) inserted successfully.
# CardInstance (NG, 80, default) inserted successfully.
# CardInstance (NG, 81, default) inserted successfully.
# CardInstance (NG, 82, default) inserted successfully.
# CardInstance (NG, 92, default) inserted successfully.
# CardInstance (NG, 94, default) inserted successfully.
# CardInstance (NG, 95, default) inserted successfully.
# CardInstance (NG, 97, default) inserted successfully.
# CardInstance (NG, 100, default) inserted successfully.
# CardInstance (NG, 102, default) inserted successfully.
# CardInstance (NG, 106, default) inserted successfully.
# CardInstance (NG, 107, default) inserted successfully.
# CardInstance (NG, 109, default) inserted successfully.
# CardInstance (NG, 111, default) inserted successfully.
# CardInstance (GRI, 38, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (BS, 42, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (AQ, 45, default) inserted successfully.
# CardInstance (DRV, 8, default) inserted successfully.
# Selling card inserted successfully
# Disposed card inserted successfully
# CardInstance (EVO, 24, Reverse Holo) inserted successfully.
# CardInstance (DR, 93, default) inserted successfully.
# CardInstance (AQ, 24, default) inserted successfully.
# CardInstance (AQ, 54, default) inserted successfully.
# CardInstance (AQ, 80, default) inserted successfully.
# CardInstance (AQ, 108, default) inserted successfully.
# CardInstance (EX, 124, default) inserted successfully.
# CardInstance (EX, 130, default) inserted successfully.
# ### Completed! ###
